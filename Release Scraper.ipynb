# %%
import requests
from bs4 import BeautifulSoup as BS

# %%
url = "https://www.discogs.com/search/?page=1"

request = requests.get(url)

BSR = BS(request.text)

RT = BSR.find("div", {"role":"main"})
print(RT)
# Out:
# <div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options


chrome_options = Options()
chrome_options.add_argument("--headless")  

dr = webdriver.Chrome()
dr.get("https://www.discogs.com/search/?page=1")
bs = BeautifulSoup(dr.page_source,"html.parser")
RT = bs.find_all("li", {"class": "card card_large float_fix shortcut_navigable"})
for result in RT:
    title = result.find("a", {"class": "search_result_title"})
    artist = result.find("div", {"class": "card-artist-name"}).find("a")
    print(title["title"])
    print(artist["title"])
    print()
# Out:
# Brat And It’s Completely Different
# Charli XCX
#
# Mayhem
# Lady Gaga
#
# Mayhem
# Lady Gaga
#
# Mayhem
# Lady Gaga
#
# Paranoid
# Black Sabbath
#
# Mayhem
# Lady Gaga
#
# Mayhem
# Lady Gaga
#
# Eternal Sunshine Deluxe: Brighter Days Ahead
# Ariana Grande
#
# I Said I Love You First
# Selena Gomez
#
# Mayhem
# Lady Gaga
#
# Mayhem
# Lady Gaga
#
# The Overview
# Steven Wilson
#
# Clear Lake Audiotorium
# De La Soul
#
# Foxes In The Snow
# Jason Isbell
#
# The Overview
# Steven Wilson
#
# The Overview
# Steven Wilson
#
# Oceanside Countryside
# Neil Young
#
# Mayhem
# Lady Gaga
#
# Mayhem
# Lady Gaga
#
# Mayhem
# Lady Gaga
#
# The Overview
# Steven Wilson
#
# Charm
# Clairo (2)
#
# Multiple
# Joe Henderson
#
# Autobahn (50th Anniversary Edition)
# Kraftwerk
#
# Mayhem
# Lady Gaga
#
# The Overview
# Steven Wilson
#
# Mayhem
# Lady Gaga
#
# Mayhem
# Lady Gaga
#
# Live From Fenway Park
# Noah Kahan
#
# Eternal Sunshine Deluxe: Brighter Days Ahead
# Ariana Grande
#
# ...

# %%
! pip install webdriver-manager

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode
